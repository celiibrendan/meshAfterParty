# %%
#importing the meshAfterParty module
from os import sys
sys.path.append("/meshAfterParty/")
from importlib import reload

# %%
import datajoint_utils as du
du = reload(du)

import minfig
du.config_celii()
du.set_minnie65_config_segmentation(minfig)

minnie,schema = du.configure_minnie_vm()
# Out:
# WARNING - 2020-11-26 08:38:08,842 - trimesh_repair - Need to pip install annotationframeworkclient to repair mesh with pychunkedgraph
# WARNING - 2020-11-26 08:38:08,844 - trimesh_io - Need to pip install annotationframeworkclient to use dataset_name parameters
# INFO - 2020-11-26 08:38:09,030 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2020-11-26 08:38:09,031 - settings - Setting database.user to celiib
# INFO - 2020-11-26 08:38:09,032 - settings - Setting database.password to newceliipass
# INFO - 2020-11-26 08:38:09,033 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2020-11-26 08:38:09,034 - settings - Setting database.user to celiib
# INFO - 2020-11-26 08:38:09,035 - settings - Setting database.password to newceliipass
# INFO - 2020-11-26 08:38:09,039 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2020-11-26 08:38:09,039 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-11-26 08:38:09,051 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# INFO - 2020-11-26 08:38:09,215 - settings - Setting enable_python_native_blobs to True
# Connecting celiib@at-database.ad.bcm.edu:3306

# %% [markdown]
# # Download Neuron

# %%
minnie.Decomposition() & "n_somas=1" & "n_faces > 600000"
# Out:
# *segment_id    *decimation_ve *decimation_ra decomposit n_vertices     n_faces     n_error_limbs  n_same_soma_mu n_multi_soma_t n_somas     n_limbs     n_branches     max_limb_n_bra skeletal_lengt max_limb_skele median_branch_ width_median   width_no_spine width_90_perc  width_no_spine n_spines     spine_density  spines_per_bra skeletal_lengt n_spine_eligib spine_density_ spines_per_bra total_spine_vo spine_volume_m spine_volume_d spine_volume_d spine_volume_p run_time
# +------------+ +------------+ +------------+ +--------+ +------------+ +---------+ +------------+ +------------+ +------------+ +---------+ +---------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +-----------+
# 86469113488474 0              0.25           =BLOB=     581524         1173901     0              0              0              1           9           396            182            9105762.417662 4417913.111483 14003.905      75.417         75.417         362.451        321.41         1506         0.000165389775 3.803030303030 3333922.996    110            nan            nan            65843283280.18 25258010.27633 7230.946763168 19749.49132273 598575302.5470 1069.7304
# 86469113488474 0              0.25           =BLOB=     499834         1012043     0              0              0              1           6           226            82             5822019.539324 2537740.721900 13125.606      111.685        111.685        499.479        458.025        2247         0.000385948550 9.942477876106 2797048.724    102            nan            nan            114016969482.3 31980749.06141 19583.74902595 40763.31188085 1117813426.297 1109.6195
# 86469113488474 0              0.25           =BLOB=     380482         782797      0              0              0              1           9           272            202            5447324.215061 3642525.625192 9876.813       79.649         79.649         270.025        257.602        885          0.000162465086 3.253676470588 2309022.528    72             nan            nan            68769148892.91 46189481.96333 12624.39065087 29782.79685840 955127067.9571 553.3898
# 86469113488474 0              0.25           =BLOB=     495419         1019870     0              0              0              1           5           251            152            6523530.868981 3362727.797990 12649.553      72.507         72.507         363.074        327.354        1010         0.000154824131 4.023904382470 2354563.584    63             nan            nan            45013258229.17 22156579.89999 6900.137231388 19117.45282015 714496162.3677 1373.9606
# 86469113488474 0              0.25           =BLOB=     305682         627133      0              0              0              1           5           111            41             3411237.943903 1007323.280333 14962.232      77.154         77.154         429.671        361.291        990          0.000290217222 8.918918918918 1501288.802    33             nan            nan            66275862286.60 41122618.91065 19428.68347986 44145.97790799 2008359463.230 1606.7856
# 86469113488474 0              0.25           =BLOB=     394856         804168      0              0              0              1           7           113            43             4985916.801286 1922276.226004 22004.931      129.881        129.881        398.909        362.133        1248         0.000250305019 11.04424778761 3159610.411    55             nan            nan            46807947406.55 19745256.37232 9388.032185871 14814.46802542 851053589.2101 3337.4618
# 86469113488474 0              0.25           =BLOB=     433156         879857      0              0              0              1           5           132            44             3980175.321212 1950608.859923 18382.244      134.043        134.043        559.787        470.169        1676         0.000421086978 12.69696969696 2127645.6      55             nan            nan            98609141635.58 36060481.75332 24775.07488427 46346.60097319 1792893484.283 3844.7428
# 86469113488474 0              0.25           =BLOB=     333547         690610      1              1              0              1           6           227            150            5923256.260350 3562420.952841 15945.722      91.936         91.936         247.021        245.172        141          2.380447405995 0.621145374449 871126.173     30             nan            nan            6818450888.328 26686104.13832 1151.132179434 7827.167980554 227281696.2776 1224.9961
# 86469113488474 0              0.25           =BLOB=     601749         1218939     0              0              0              1           9           278            100            9516993.070636 3679919.833727 20041.486      77.39          77.39          341.087        310.914        1160         0.000121887238 4.172661870503 2900033.012    61             nan            nan            58696439718.79 21521972.34665 6167.540449293 20239.92122707 962236716.7015 4487.8633
# 86469113488475 0              0.25           =BLOB=     494388         996213      0              0              0              1           7           284            123            6505173.317173 2919316.475631 13900.986      89.995         89.995         427.133        353.794        1501         0.000230739432 5.285211267605 2773464.639    78             nan            nan            76659243788.73 28240983.30766 11784.35070843 27640.24560139 982810817.8043 2013.945
# 86469113488475 0              0.25           =BLOB=     366929         748771      0              0              0              1           6           91             36             2932186.063391 1597848.646602 15241.916      308.844        281.593        540.086        464.908        1670         0.000569540937 18.35164835164 2131429.77     54             nan            nan            108482939022.9 40564286.23784 36997.29030750 50896.79263647 2008943315.238 2750.2024
# 86469113488475 0              0.25           =BLOB=     519792         1034699     0              0              0              1           5           478            342            7503557.566367 6379782.767765 8754.621       83.751         83.751         219.475        217.849        276          3.678255248378 0.577405857740 801905.048     55             nan            nan            17093718286.48 31537859.04816 2278.081847883 21316.38693274 310794877.9361 1920.668
#    ...
#  (Total: 11020)

# %%
neuron_obj = (minnie.Decomposition() & "segment_id=864691134884740858").fetch1("decomposition")
# Out:
# INFO - 2020-11-26 08:38:10,205 - settings - Setting enable_python_native_blobs to True
# INFO - 2020-11-26 08:38:10,382 - settings - Setting enable_python_native_blobs to True
# Decompressing Neuron in minimal output mode...please wait
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-7204979c120f> in <module>
# ----> 1 neuron_obj = (minnie.Decomposition() & "segment_id=864691134884740858").fetch1("decomposition")
#
# /usr/local/lib/python3.6/dist-packages/datajoint/fetch.py in __call__(self, squeeze, download_path, *attrs)
#     243         else:  # fetch some attributes, return as tuple
#     244             attributes = [a for a in attrs if not is_key(a)]
# --> 245             result = self._expression.proj(*attributes).fetch(squeeze=squeeze, download_path=download_path)
#     246             if len(result) != 1:
#     247                 raise DataJointError('fetch1 should only return one tuple. %d tuples were found' % len(result))
#
# /usr/local/lib/python3.6/dist-packages/datajoint/fetch.py in __call__(self, offset, limit, order_by, format, as_dict, squeeze, download_path, *attrs)
#     201                     raise e
#     202                 for name in heading:
# --> 203                     ret[name] = list(map(partial(get, heading[name]), ret[name]))
#     204                 if format == "frame":
#     205                     ret = pandas.DataFrame(ret).set_index(heading.primary_key)
#
# /usr/local/lib/python3.6/dist-packages/datajoint/fetch.py in _get(connection, attr, data, squeeze, download_path)
#      52
#      53     if attr.is_filepath:
# ---> 54         return adapt(extern.download_filepath(uuid.UUID(bytes=data))[0])
#      55
#      56     if attr.is_attachment:
#
# /meshAfterParty/datajoint_utils.py in get(self, filepath)
#     136         #3) use the decompress method
#     137         recovered_neuron = nru.decompress_neuron(filepath=filepath,
# --> 138                      original_mesh=dec_mesh)
#     139
#     140         return recovered_neuron
#
# /meshAfterParty/neuron_utils.py in decompress_neuron(filepath, original_mesh, suppress_output)
#    1431
#    1432
# -> 1433         recovered_preprocessed_data["soma_meshes"] = [original_mesh.submesh([k],append=True,repair=False) for k in loaded_compression["soma_meshes_face_idx"]]
#    1434
#    1435         """
#
# /meshAfterParty/neuron_utils.py in <listcomp>(.0)
#    1431
#    1432
# -> 1433         recovered_preprocessed_data["soma_meshes"] = [original_mesh.submesh([k],append=True,repair=False) for k in loaded_compression["soma_meshes_face_idx"]]
#    1434
#    1435         """
#
# /usr/local/lib/python3.6/dist-packages/trimesh/base.py in submesh(self, faces_sequence, **kwargs)
#    2462         return util.submesh(mesh=self,
#    2463                             faces_sequence=faces_sequence,
# -> 2464                             **kwargs)
#    2465
#    2466     @caching.cache_decorator
#
# TypeError: submesh() got an unexpected keyword argument 'repair'
